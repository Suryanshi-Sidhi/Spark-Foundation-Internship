# %% [markdown]
# # #Task 5 -  Exploratory Data Analysis

# %% [markdown]
# ## Problem Statement : Perform ‘Exploratory Data Analysis’ on the provided dataset ‘SampleSuperstore’

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.set_option("display.max_columns" , None)
pd.set_option("display.max_rows" , None)

# %% [markdown]
# # #Read the SampleSuperstore file

# %%
store = pd.read_csv(r"C:\Users\home\Desktop\SPARK\SampleSuperstore.csv")
store.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
store.shape
# Out:
# (9994, 13)

# %% [markdown]
# ### #Removing the country column

# %%
store = store.drop(["Country"] , axis = 1)

# %%
store.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# ## #Checking null counts

# %%
store.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ## #Checking  value counts

# %%
store['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %% [markdown]
# # #Plotting

# %%
plt.figure(figsize=(18,8))
plt.bar('Sub-Category' , 'Category' , data = store)
plt.show()

# %%
plt.figure(figsize=(10,8))

pd.crosstab(store["Quantity"],store["Category"],store["Profit"],aggfunc='sum').plot(kind="bar",stacked=True)

# %%
plt.figure(figsize=(10,10))

store.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.title('Total Profit and Sales per Sub-Category')
plt.show()
# Out:
# C:\Users\home\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(18,10))
sns.countplot(x="Sub-Category", hue="Region", data=store)
plt.show()

# %% [markdown]
# # #Pie- Chart----------------------

# %%
plt.figure(figsize=(12,12))

store['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")

# %%
plt.figure(figsize=(8,8))

sns.countplot(x="Category", hue="Region", data=store)

# %% [markdown]
# # #Scatter Plot-------------------------

# %%
sns.scatterplot("Sales",'Profit',data=store)
